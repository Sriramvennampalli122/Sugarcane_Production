# %% [markdown]
# importing all the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# loading the processed dataset as a dataframe

# %%
df=pd.read_csv("cleaned_sugarcane_production_list.csv")

# %%
df
# Out:
#      Unnamed: 0    Country      Continent  Production (Tons)  \
# 0             0     Brazil  South America        768678382.0
# 1             1      India           Asia        348448000.0
# 2             2      China           Asia        123059739.0
# 3             3   Thailand           Asia         87468496.0
# 4             4   Pakistan           Asia         65450704.0
# ..          ...        ...            ...                ...
# 97           97      Spain         Europe              394.0
# 98           98    Lebanon           Asia               97.0
# 99          100  Singapore           Asia               50.0
# 100         101      Samoa        Oceania               12.0
# 101         102      Syria           Asia                1.0
#
#      Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                     3668531.0         10226205.0              751675.0
# 1                      260721.0          4950000.0              703935.0
# ...

# %% [markdown]
# deleting the unwanted column from the dataset

# %%
del df["Unnamed: 0"]

# %% [markdown]
# Calculating the number of countries producing sugarcane from each continent

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# plotting a bar graph and pie chart for comparing the number of sugarcane production countries of each continent

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
df["Continent"].value_counts().plot(kind="pie",autopct="%0.1f")
plt.subplot(2,2,2)
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# From the above pie chart most percent of the countries that produce sugarcane are from African continent  which were around 38 followed by Asia with 25 countries and other continents.The least number of countries were from Europe with only 2 countries

# %% [markdown]
# using distplot to understand the type of distribution happening,Production (Tons),Production per Person (Kg),Acreage (Hectare),Yield (Kg / Hectare)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production per Person (Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage (Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df["Yield (Kg / Hectare)"])
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\1130486837.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production (Tons)"])
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\1130486837.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# From the distribution graph of production(Tons) column we can observe that the bell curve is from 0 to 2 on x-axis which means mostly of the countries produce (0to2)x10^8 tons at most. There is an outlier at 0 which indicates large number of countries produce less than 1x10^8 ton.we can also observe that the graph is right skewed which indicate there were countries which produce more than 200 million tons

# %% [markdown]
# From the distribution graph of production per person(kg) column we can observe that the bell curve is froming at -1 to 2 on x-axis which means in most of the countries a preson can produce less than 10^6 kgs to 2x10^6 kgs at most. There is an outlier at 0 which indicates in large number of countries production per person is less than 10^8 kgs.we can also observe that the graph is right skewed which indicate there were countries in which production per person is more than 2 million kgs

# %% [markdown]
# From the distribution graph of the Acreage (Hectare) column, we can observe that the bell curve spans from 0 to 0.2 on the x-axis. This indicates that most sugarcane-producing countries have less than 1 million hectares or, at most, 2 million hectares of land dedicated to sugarcane cultivation. There is an outlier at 0, which suggests that a significant number of countries have close to 1 million hectares of land for sugarcane production. Additionally, the graph is right-skewed, indicating the presence of some countries with more than 10 million hectares of land allocated for sugarcane cultivation.

# %% [markdown]
# From the distribution graph of the Yield (kg/Hectare) column, we can observe that the data does not form a perfect bell curve. It can be noted that the majority of countries have a yield ranging between 1 to 1.5 million kg per hectare, with the highest concentration of countries achieving yields of more than 1 million kg per hectare.

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production per Person (Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage (Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df["Yield (Kg / Hectare)"])
# Out:
# <Axes: ylabel='Yield (Kg / Hectare)'>

# %% [markdown]
# we can obesrve from the above boxplot that every column has outliers except Yield

# %% [markdown]
# creating new dataframe existing country,production column

# %%
 df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Spain                  394.0
# Lebanon                 97.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [102 rows x 1 columns]

# %% [markdown]
# Total production of all countries of the world

# %%
x=df["Production (Tons)"].sum()
print(x)
# Out:
# 1887379367.0

# %% [markdown]
# Finding the contribution percentage of each country in total production of world

# %%
df_new["Production_(Tons)_percent"]=(df_new["Production (Tons)"]/x)*100

# %%
df_new
# Out:
#            Production (Tons)  Production_(Tons)_percent
# Country
# Brazil           768678382.0               4.072729e+01
# India            348448000.0               1.846200e+01
# China            123059739.0               6.520138e+00
# Thailand          87468496.0               4.634389e+00
# Pakistan          65450704.0               3.467809e+00
# ...                      ...                        ...
# Spain                  394.0               2.087551e-05
# Lebanon                 97.0               5.139401e-06
# Singapore               50.0               2.649176e-06
# Samoa                   12.0               6.358022e-07
# Syria                    1.0               5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production_(Tons)_percent"].head(10).plot(kind="pie",autopct="%0.1f")
# Out:
# <Axes: ylabel='Production_(Tons)_percent'>

# %% [markdown]
# From the above pie chart, it can be observed that Brazil contributes the largest share to the total global sugarcane production, followed by India, and then China.

# %%
ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\3836565765.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# The above bar graph displays the top 10 sugarcane-producing countries, with Brazil leading the chart at over 750 million tons of production, followed by India and China in second and third places, respectively.

# %%
df_yld=df.sort_values("Yield (Kg / Hectare)",ascending=False)
ax=sns.barplot(data=df_yld.head(10),x="Country",y="Yield (Kg / Hectare)",palette="bright")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\2628899902.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_yld.head(10),x="Country",y="Yield (Kg / Hectare)",palette="bright")
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\2628899902.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# The above bar graph showcases the top 10 sugarcane-producing countries with the largest Yield. Guatemala leads the chart with over 1.2 million Yield , followed by senegal and Egypt in second and third places, respectively.

# %%
df_acr=df.sort_values("Acreage (Hectare)",ascending=False)
ax=sns.barplot(data=df_acr.head(10),x="Country",y="Acreage (Hectare)",palette="bright")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\2597810453.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_acr.head(10),x="Country",y="Acreage (Hectare)",palette="bright")
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\2597810453.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# The above bar graph showcases the top 10 sugarcane-producing countries with the largest cultivated areas. Brazil leads the chart with over 10 million hectares of land dedicated to sugarcane cultivation, followed by India and China in second and third places, respectively.

# %%
df_prd=df.sort_values("Production (Tons)",ascending=False)
ax=sns.barplot(data=df_prd.head(10),x="Country",y="Production (Tons)",palette="bright")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\736512583.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_prd.head(10),x="Country",y="Production (Tons)",palette="bright")
# C:\Users\venna\AppData\Local\Temp\ipykernel_13744\736512583.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [raw]
# The above bar graph displays the top 10 sugarcane-producing countries, with Brazil leading the chart at over 750 million tons of production, followed by India and China in second and third places, respectively.
# conclusions:
# ->production of the country does not depend on the Yield
# ->production of the country is directly proportional to the cultivation land the land had.

# %%
df_1=df.copy()
del df_1["Country"]
del df_1["Continent"]

# %% [markdown]
# Finding the correlation between the variable of the sugar production dataset

# %%
df_1.corr()
# Out:
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.352369
# Production per Person (Kg)           0.352369                    1.000000
# Acreage (Hectare)                    0.997550                    0.341974
# Yield (Kg / Hectare)                 0.121125                    0.226719
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)
# Production (Tons)                    0.997550              0.121125
# Production per Person (Kg)           0.341974              0.226719
# Acreage (Hectare)                    1.000000              0.107826
# Yield (Kg / Hectare)                 0.107826              1.000000

# %%
sns.heatmap(df_1.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The above heatmap shows the correlation between different variable of sugar production dataset. we can obesrve that  sugarcane production and acreage, a correlation of 1 would imply that every increase in the acreage results in a proportional and consistent increase in sugarcane production.

# %%
sns.scatterplot(data=df,x="Acreage (Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# From the above scatterplot, we can observe that Production and Acreage exhibit a direct proportional relationship. This suggests that as the acreage dedicated to sugarcane cultivation increases, the production of sugarcane also increases in a consistent manner.

# %%
sns.scatterplot(data=df,x="Yield (Kg / Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# From the above scatterplot we can observe that there is no relation between production and Yield

# %% [markdown]
# Grouping dataset using continent attribute and creating a new dataset

# %%
df_cont=df.groupby("Continent").sum()

# %%
df_cont
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                  10144110.0
# Asia                 721930425.0                   3120808.0
# Europe                    5823.0                       536.0
# North America        173995947.0                  15420953.0
# Oceania               36177574.0                   3158066.0
# South America        865588126.0                  10228540.0
#
# ...

# %%
df_cont=df_cont.sort_values("Production (Tons)",ascending=False)

# %% [markdown]
# Arranging the continents with the number of countries in them

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_cont["Production (Tons)"].plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# From the above bar graph, it can be observed that South America has the highest sugarcane production, followed by Asia and North America. This indicates that sugarcane production is not directly related to the number of countries within a continent, as some continents with fewer countries still have higher production due to favorable conditions and resources.

# %%
df_cont["Acreage (Hectare)"].plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# From the above bar graph, it can be observed that South America has the highest sugarcane production, followed by Asia and North America. This suggests that sugarcane production is directly linked to the cultivation area available within each continent, highlighting the importance of large-scale agricultural land in driving higher production volumes.

# %%
df_cont["no_of_countries"]=df.groupby("Continent").count()["Country"]

# %%
df_cont
# Out:
#                                                          Country  \
# Continent
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# Europe                                             PortugalSpain
#
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# South America        865588126.0                  10228540.0
# Asia                 721930425.0                   3120808.0
# North America        173995947.0                  15420953.0
# Africa                89681472.0                  10144110.0
# Oceania               36177574.0                   3158066.0
# Europe                    5823.0                       536.0
#
# ...

# %%
cont_nam=df_cont.index.to_list()
sns.lineplot(data=df_cont,x="no_of_countries",y="Production (Tons)")
plt.xticks(df_cont["no_of_countries"],cont_nam,rotation=90)
plt.show()

# %% [markdown]
# The above line graph illustrates the relationship between sugarcane production and the number of countries in each continent. It highlights how production levels vary regardless of the number of countries, providing insights into regional contributions to global sugarcane output.

# %%
df_cont1=df_cont

# %%
del df_cont1["Country"]

# %%
df_cont1.corr()
# Out:
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.143100
# Production per Person (Kg)           0.143100                    1.000000
# Acreage (Hectare)                    0.994897                    0.073059
# Yield (Kg / Hectare)                 0.104312                    0.514924
# no_of_countries                      0.109244                    0.526387
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)  \
# Production (Tons)                    0.994897              0.104312
# Production per Person (Kg)           0.073059              0.514924
# Acreage (Hectare)                    1.000000              0.126764
# Yield (Kg / Hectare)                 0.126764              1.000000
# no_of_countries                      0.132817              0.983807
#
#                             no_of_countries
# Production (Tons)                  0.109244
# ...

# %%
sns.heatmap(df_cont.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The above heatmap illustrates the correlations between various variables. Production shows a near-perfect correlation of 1 (approximately) with Acreage, indicating a strong direct relationship between these two factors. Similarly, Yield exhibits a near-perfect correlation of 1 (approximately) with the number of countries, highlighting their close relationship.

# %%
df_cont["Production (Tons)"].plot(kind="pie",autopct="%0.1f")
# Out:
# <Axes: ylabel='Production (Tons)'>

# %% [markdown]
# The above pie chart illustrates the contribution of each continent to global sugarcane production, showcasing the varying levels of output across regions. It provides a clear visual representation of how continents compare in their share of the world's total sugarcane production
